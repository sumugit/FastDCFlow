# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
parato_df = pd.read_csv('/workspace/Eval/cfs/CF_MOGA/bank/cfs_targetenc_bank_loss_neg_1.csv')
parato_df.head()
# Out:
#       yloss   prox_loss
# 0  0.000015  146.457764
# 1  0.000013  153.413742
# 2  0.005434   40.688480
# 3  0.002195   52.326572
# 4  0.000002  886.642578

# %%
# 可視化
plt.scatter(parato_df['yloss'], parato_df['prox_loss'])
